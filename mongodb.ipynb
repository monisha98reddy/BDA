# %% [markdown]
# # 1.Find all the records for city “CHICOPEE".

# %% [markdown]
# ![Screenshot%202021-08-03%20at%205.12.38%20PM.png](attachment:Screenshot%202021-08-03%20at%205.12.38%20PM.png)

# %% [markdown]
# # 2.Display all the distinct State names which are there in this dataset.

# %% [markdown]
# ![Screenshot%202021-08-03%20at%205.13.56%20PM.png](attachment:Screenshot%202021-08-03%20at%205.13.56%20PM.png)

# %% [markdown]
# # 3.The records of "TOLLAND" or "MONTGOMERY" city.

# %% [markdown]
# ![Screenshot%202021-08-03%20at%205.18.08%20PM.png](attachment:Screenshot%202021-08-03%20at%205.18.08%20PM.png)

# %% [markdown]
# # 4.The list of cities name for the state “VA”

# %% [markdown]
# ![Screenshot%202021-08-03%20at%205.45.03%20PM.png](attachment:Screenshot%202021-08-03%20at%205.45.03%20PM.png)

# %% [markdown]
# # 5.The list of cities where "population” is greater than 33801.

# %% [markdown]
# ![Screenshot%202021-08-03%20at%205.50.08%20PM.png](attachment:Screenshot%202021-08-03%20at%205.50.08%20PM.png)

# %% [markdown]
# # 6.The names of the state and its total population whose poulaiton is greater than 5000000

# %% [markdown]
# ![Screenshot%202021-08-03%20at%206.02.16%20PM.png](attachment:Screenshot%202021-08-03%20at%206.02.16%20PM.png)
