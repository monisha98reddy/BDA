# %% [markdown]
# # Create a MongoDB Database and collection and answer the following questions

# %% [markdown]
# # 1.Write a MongoDB query to display all the restaurant which is in the borough Bronx.

# %% [markdown]
# ![Screenshot%202021-08-11%20at%208.48.57%20PM.png](attachment:Screenshot%202021-08-11%20at%208.48.57%20PM.png)

# %% [markdown]
# # 2.Write a MongoDB query to display the next 5 restaurants after skipping first 5 which are in the borough Bronx.

# %% [markdown]
# ![Screenshot%202021-08-11%20at%208.51.28%20PM.png](attachment:Screenshot%202021-08-11%20at%208.51.28%20PM.png)

# %% [markdown]
# # 3.Write a MongoDB query to find the restaurants that achieved a score is more than 80 but less than 100.

# %% [markdown]
# ![Screenshot%202021-08-11%20at%209.47.30%20PM.png](attachment:Screenshot%202021-08-11%20at%209.47.30%20PM.png)

# %% [markdown]
# # 4.Write a MongoDB query to find the restaurants that do not prepare any cuisine of 'American' and their grade score more than 70 and lattitude less than -65.754168.

# %% [markdown]
# ![Screenshot%202021-08-11%20at%209.52.49%20PM.png](attachment:Screenshot%202021-08-11%20at%209.52.49%20PM.png)
