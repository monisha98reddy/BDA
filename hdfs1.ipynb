# %% [markdown]
# # 1. Create a directory in HDFS whose path should be /sales/2020

# %% [markdown]
# ![Screenshot%202021-08-09%20at%209.07.54%20PM.png](attachment:Screenshot%202021-08-09%20at%209.07.54%20PM.png)

# %% [markdown]
# # 2.  Create a Linux file and write some data into it as shown in the below screenshot.

# %% [markdown]
# ![Screenshot%202021-08-09%20at%209.44.38%20PM.png](attachment:Screenshot%202021-08-09%20at%209.44.38%20PM.png)

# %% [markdown]
# ![Screenshot%202021-08-09%20at%209.44.27%20PM.png](attachment:Screenshot%202021-08-09%20at%209.44.27%20PM.png)

# %% [markdown]
# # 3. You save this Linux file into HDFS in the folder “/sales/2020” which you create in the step no 1.

# %% [markdown]
# ![Screenshot%202021-08-09%20at%209.21.25%20PM.png](attachment:Screenshot%202021-08-09%20at%209.21.25%20PM.png)

# %% [markdown]
# # 4.  Execute a command to verify number of files, block for each file, rack information of this folder “/sales”

# %% [markdown]
# ![Screenshot%202021-08-09%20at%209.21.36%20PM.png](attachment:Screenshot%202021-08-09%20at%209.21.36%20PM.png)

# %% [markdown]
# # 5.  Execute a command to delete the “/sales” folder

# %% [markdown]
# ![Screenshot%202021-08-09%20at%209.42.44%20PM.png](attachment:Screenshot%202021-08-09%20at%209.42.44%20PM.png)

# %% [markdown]
# # 6 .  Execute command to verify “/sales” folder is deleted.

# %% [markdown]
# ![Screenshot%202021-08-09%20at%209.42.51%20PM.png](attachment:Screenshot%202021-08-09%20at%209.42.51%20PM.png)
