# %% [markdown]
# # 1.Let’s first insert one million records into MongoDB using mongo console

# %% [markdown]
# ![Screenshot%202021-08-03%20at%203.28.46%20PM.png](attachment:Screenshot%202021-08-03%20at%203.28.46%20PM.png)

# %% [markdown]
# ![Screenshot%202021-08-03%20at%203.36.28%20PM.png](attachment:Screenshot%202021-08-03%20at%203.36.28%20PM.png)

# %% [markdown]
# # 2. Let’s find out those documents where value of money field is less than 500 and sort them using name field . You will notice that this query will fail to execute as it needs more than 32 MB to doing sorting.

# %% [markdown]
# ![Screenshot%202021-08-03%20at%203.37.20%20PM.png](attachment:Screenshot%202021-08-03%20at%203.37.20%20PM.png)

# %% [markdown]
# # 3.   Now, let’s find out those documents where name field has value ‘Venkat’ and value money field is greater than 10. We will add a new field “city” value “Pune” into those documents.

# %% [markdown]
# ![Screenshot%202021-08-03%20at%203.45.58%20PM.png](attachment:Screenshot%202021-08-03%20at%203.45.58%20PM.png)

# %%
var cur=db.mycol.find({name:'Venkat',money:{$gt:10}})
while(cur.hasNext()){
    var obj =cur.next()
    obj.city = 'Pune';
    db.mycol.save(obj);
    
}

# %% [markdown]
# # 4. Now let’s update those records where name field has value “Rajesh” to add an array field containing below records

# %% [markdown]
# ![Screenshot%202021-08-03%20at%203.39.02%20PM.png](attachment:Screenshot%202021-08-03%20at%203.39.02%20PM.png)

# %% [markdown]
# # 5. Let’s remove those records where name field is “Venkat”

# %% [markdown]
# ![Screenshot%202021-08-03%20at%203.39.48%20PM.png](attachment:Screenshot%202021-08-03%20at%203.39.48%20PM.png)

# %% [markdown]
# # Question 6:Remove those records where name is either “Shilpi” or money field has value greater than 100.

# %% [markdown]
# ![Screenshot%202021-08-03%20at%203.42.45%20PM.png](attachment:Screenshot%202021-08-03%20at%203.42.45%20PM.png)
